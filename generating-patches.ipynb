# %%
import cv2
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm, trange
from joblib import Parallel, delayed
from patch_gen import PatchGenerator

# %matplotlib inline

# %%
path = "/kaggle/input/cbisddsm/CBIS_DDSM/"

# %%
patch_gen = PatchGenerator(path, patch_size=(256,256), max_patches=50, min_ratio=0.10, max_black_space=0.5)

# %%
i = np.random.randint(0, len(patch_gen.imgs_path))
example = patch_gen.imgs_path[i]

# %%
bg_patch = patch_gen._create_background_patch(example)
mass_patch, _, _ = patch_gen._create_mass_patch(example, 0.10)

# %%
_, axs = plt.subplots(1,2)

axs[0].imshow(bg_patch, cmap="bone")
axs[0].set_title("Background patch")

axs[1].imshow(mass_patch, cmap="bone")
axs[1].set_title("Mass patch")

plt.tight_layout();

# %%
patch_gen.generate_all()
# Out:
#   0%|          | 0/2458 [00:00<?, ?it/s]
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.025
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.025
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.0015625
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.00078125
# Reducing min ratio to 4.8828125e-05
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.025
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.025
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 0.00625
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.025
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 0.0125
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 4.8828125e-05
# Reducing min ratio to 2.44140625e-05
# Reducing min ratio to 1.220703125e-05
# Reducing min ratio to 6.103515625e-06
# Reducing min ratio to 0.05
# Reducing min ratio to 3.0517578125e-06
# Reducing min ratio to 1.52587890625e-06
# Reducing min ratio to 7.62939453125e-07
# Reducing min ratio to 3.814697265625e-07
# Reducing min ratio to 1.9073486328125e-07
# Reducing min ratio to 9.5367431640625e-08
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 4.8828125e-05
# Reducing min ratio to 2.44140625e-05
# Reducing min ratio to 1.220703125e-05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.025
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 0.00078125
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 4.8828125e-05
# Reducing min ratio to 2.44140625e-05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 4.8828125e-05
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 2.44140625e-05
# Reducing min ratio to 1.220703125e-05
# Reducing min ratio to 6.103515625e-06
# Reducing min ratio to 3.0517578125e-06
# Reducing min ratio to 1.52587890625e-06
# Reducing min ratio to 7.62939453125e-07
# Reducing min ratio to 3.814697265625e-07
# Reducing min ratio to 1.9073486328125e-07
# Reducing min ratio to 9.5367431640625e-08
# Reducing min ratio to 4.76837158203125e-08
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 0.00078125
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 4.8828125e-05
# Reducing min ratio to 2.44140625e-05
# Reducing min ratio to 1.220703125e-05
# Reducing min ratio to 6.103515625e-06
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 4.8828125e-05
# Reducing min ratio to 2.44140625e-05
# Reducing min ratio to 1.220703125e-05
# Reducing min ratio to 6.103515625e-06
# Reducing min ratio to 3.0517578125e-06
# Reducing min ratio to 1.52587890625e-06
# Reducing min ratio to 7.62939453125e-07
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 4.8828125e-05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 0.00625
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 4.8828125e-05
# Reducing min ratio to 0.000390625
# Reducing min ratio to 2.44140625e-05
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 1.220703125e-05
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 6.103515625e-06
# Reducing min ratio to 3.0517578125e-06
# Reducing min ratio to 1.52587890625e-06
# Reducing min ratio to 7.62939453125e-07
# Reducing min ratio to 3.814697265625e-07
# Reducing min ratio to 1.9073486328125e-07
# Reducing min ratio to 9.5367431640625e-08
# Reducing min ratio to 4.76837158203125e-08
# Reducing min ratio to 2.384185791015625e-08
# Reducing min ratio to 1.1920928955078126e-08
# Reducing min ratio to 0.05
# Reducing min ratio to 5.960464477539063e-09
# Reducing min ratio to 2.9802322387695314e-09
# Reducing min ratio to 1.4901161193847657e-09
# Reducing min ratio to 7.450580596923829e-10
# Reducing min ratio to 3.7252902984619143e-10
# Reducing min ratio to 1.8626451492309571e-10
# Reducing min ratio to 9.313225746154786e-11
# Reducing min ratio to 4.656612873077393e-11
# Reducing min ratio to 2.3283064365386964e-11
# Reducing min ratio to 1.1641532182693482e-11
# Reducing min ratio to 5.820766091346741e-12
# Reducing min ratio to 2.9103830456733705e-12
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.00078125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.000390625
# Reducing min ratio to 0.0001953125
# Reducing min ratio to 9.765625e-05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 4.8828125e-05
# Reducing min ratio to 2.44140625e-05
# Reducing min ratio to 1.220703125e-05
# Reducing min ratio to 0.0015625
# Reducing min ratio to 6.103515625e-06
# Reducing min ratio to 0.00078125
# Reducing min ratio to 3.0517578125e-06
# Reducing min ratio to 0.000390625
# Reducing min ratio to 1.52587890625e-06
# Reducing min ratio to 7.62939453125e-07
# Reducing min ratio to 3.814697265625e-07
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.025
# Reducing min ratio to 0.0125
# Reducing min ratio to 0.00625
# Reducing min ratio to 0.003125
# Reducing min ratio to 0.0015625
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Reducing min ratio to 0.05
# Parallel preprocessing done!
